# %%
import farPoint
a = farPoint.SDRCurves(100.0, 201, 0.5, 0.1, 0.01, 2, 4, useFile='ks1_SDRrec.pick')
a.fitPT()
P, T = a.interpCurve(1.01)

farPoint.SCQuerry(P, T, 0.91, 1.00, 0.)
# Out:
# [0.93836098]
# [0.93836098]
# (array([0], dtype=int64),)
# (1.0120399996904477, 0.14833192539102855)

# %%
farPoint.SCQuerry(P, T, 0.65, 1.02, 0.32357009037933304)
# Out:
# [0.30953132 0.6288258 ]
# [-0.01403877  0.30525571]
# (array([1], dtype=int64),)
# (1.0043954808436606, 0.8903251388524326)

# %%
print P
# Out:
# [[1.         1.        ]
#  [1.00095393 0.99353393]
#  [1.00188731 0.98712544]
#  [1.00280013 0.98077455]
#  [1.00369241 0.97448125]
#  [1.00456414 0.96824554]
#  [1.00541532 0.96206742]
#  [1.00624594 0.95594689]
#  [1.00705602 0.94988395]
#  [1.00784554 0.9438786 ]
#  [1.00861452 0.93793084]
#  [1.00936294 0.93204067]
#  [1.01009081 0.92620809]
#  [1.01079814 0.92043311]
#  [1.01148491 0.91471571]
#  [1.01215113 0.9090559 ]
#  [1.0127968  0.90345369]
#  [1.01342192 0.89790906]
#  [1.01402649 0.89242202]
#  [1.01461051 0.88699258]
#  [1.01517398 0.88162072]
#  [1.0157169  0.87630646]
#  [1.01623927 0.87104978]
#  [1.01674109 0.8658507 ]
#  [1.01722236 0.86070921]
#  [1.01768307 0.85562531]
#  [1.01812324 0.85059899]
#  [1.01854285 0.84563027]
#  [1.01894192 0.84071914]
#  [1.01932044 0.8358656 ]
#  [1.0196784  0.83106965]
#  [1.02001581 0.82633129]
#  [1.02033268 0.82165052]
#  [1.02062899 0.81702734]
#  [1.02090475 0.81246175]
#  [1.02115997 0.80795375]
#  [1.02139463 0.80350334]
# ...
