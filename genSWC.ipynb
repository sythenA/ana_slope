# %%
import farPoint as fp

a = fp.SWRCurves(100.0, 201, 0.5, 0.1, 0.01, 2, 4, useFile='ks1_SWRrec.pick')

# %%
a.fitPT()
p, t = a.interpCurve(1.31, 1.35)

# %%
import matplotlib.pyplot as plt
plt.plot(p[:, 0], p[:, 1])
