# %%
from farPoint import SDRCurves
import pickle


aa = SDRCurves(100.0, 201, 0.5, 0.1, 0.01, 2, 4, useFile='ks1_SDRrec.pick')
aa.getSDRLength()
# Out:
# 1053.22461457
# 460.320774706
# xs1 to reach L: 460.320774706
# flowrate: 0.00260874607476
# flowate at t1: 0.00108746323366
# z = 0.41685284903
# running two step
# running return curve
# 1.0 0.000854987973338
# 2.0 0.00271441761659
# 3.0 0.00533533995674
# 4.0 0.00861773876013
# 5.0 0.0125
# 6.0 0.0169386485199
# 7.0 0.0219006366099
# 8.0 0.0273596151468
# 9.0 0.0332938630035
# 10.0 0.0396850262992
# 11.0 0.0465172980696
# 12.0 0.0537768569587
# 13.0 0.0614514676489
# 14.0 0.0695301871865
# 15.0 0.0780031433644
# 16.0 0.086861363731
# 17.0 0.0960966411429
# 18.0 0.105701426312
# 19.0 0.115668740695
# 20.0 0.125992104989
# 21.0 0.13666547978
# 22.0 0.147683215781
# 23.0 0.159040011752
# 24.0 0.170730878616
# 25.0 0.182751108638
# 26.0 0.195096248782
# 27.0 0.207762077521
# 28.0 0.220744584567
# 29.0 0.23403995303
# 30.0 0.247644543667
# 31.0 0.261554880894
# 32.0 0.275767640324
# 33.0 0.29027963762
# 34.0 0.305087818482
# 35.0 0.320189249627
# 36.0 0.335581110643
# ...

# %%
import numpy as np
print(np.array(aa.QCompare))
pickle.dump(aa.QCompare, open('QCompare1.out', 'wb'))
# Out:
# [[ 0.70674542  1.04447308  1.07520897]
#  [ 0.79508894  1.10027339  1.02124878]
#  [ 0.90867267  1.17217705  0.96565203]
#  [ 1.06011779  1.26795133  0.90844917]
#  [ 1.27214125  1.40212423  0.84925041]
#  [ 1.59017594  1.60330379  0.78779758]
#  [ 2.12023456  1.93846584  0.72382345]
#  [ 3.18035266  2.60890182  0.65705057]
#  [ 6.36069983  4.6197239   0.58689523]]

# %%
f = open('QCompare2.out', 'rb')
b = pickle.load(f)
print(np.array(b))
# Out:
# [[ 0.84148728  1.06977173  1.01301966]
#  [ 0.94667276  1.15720123  0.97927684]
#  [ 1.08191221  1.26941486  0.94511979]
#  [ 1.26223035  1.41911496  0.91021206]
#  [ 1.5146767   1.62864311  0.87468433]
#  [ 1.89334614  1.94297933  0.83853271]
#  [ 2.52445813  2.46708036  0.80175284]
#  [ 3.78668611  3.5140062   0.76381565]]

# %%
f = open('QCompare3.out', 'rb')
b = pickle.load(f)
print(np.array(b))
# Out:
# [[ 0.76545155  1.04293332  1.03604723]
#  [ 0.82433253  1.09328183  1.01252682]
#  [ 0.89302684  1.15144315  0.98850717]
#  [ 0.97421033  1.21839553  0.96303234]
#  [ 1.07163167  1.30053906  0.93821036]
#  [ 1.1907024   1.40387805  0.91464651]
#  [ 1.33953948  1.52600953  0.88745963]
#  [ 1.53090292  1.68780001  0.86182613]
#  [ 1.78605287  1.90876028  0.83774774]
#  [ 2.14326324  2.21154285  0.81129801]
#  [ 2.6790796   2.66571563  0.78448781]
#  [ 3.57210048  3.42276247  0.75731715]
#  [ 5.35815303  4.93716962  0.72978807]]
